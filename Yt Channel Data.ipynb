# %%
# importing all required libraries
import requests
import pandas as pd
import time

# %%
# importing all required libraries
import requests
import pandas as pd
import time
#keys
API_key = 'AIzaSyCr1q6nwwJ3XOc1rAkTfyfCbcRYnOptYXI'
Channel_ID = 'UC2TZfHtB9tBH-cCzGVv5Njg'
pagetoken = ''
url = f'https://www.googleapis.com/youtube/v3/search?key={API_key}&channelId={Channel_ID}&part=snippet,id&order=date&maxResults=300&pageToken={pagetoken}'
response = requests.get(url).json()
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'VlDGm-J0eC6I-3Smc4oN9kjKbzk',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'PK',
#  'pageInfo': {'totalResults': 76, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '9rQQ5XjQPN0ETPWOuGKGa7FYFVQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'LOWGBvcqinA'},
#    'snippet': {'publishedAt': '2023-10-30T12:28:09Z',
#     'channelId': 'UC2TZfHtB9tBH-cCzGVv5Njg',
#     'title': '집에서 새벽 스터디윗미🌙자기 전 딱 1시간! 백색소음 Midnight study with me at home⭐️1 hour, no music, real time',
#     'description': 'Instagram: sweetdia_med Email: diasdiaryljy@gmail.com #의대생 #스터디윗미 #브이로그 #대학생 #공부자극 #시험기간 #수능 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LOWGBvcqinA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/LOWGBvcqinA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
#keys
API_key = 'AIzaSyCr1q6nwwJ3XOc1rAkTfyfCbcRYnOptYXI'
Channel_ID = 'UC2TZfHtB9tBH-cCzGVv5Njg'

# %%
def get_video_details(video_id):
        # collecting view,like,dislike & comment counts
        statistics = 'views,likes,dislikes,commentCount'
        url_video_stats = f'https://www.googleapis.com/youtube/v3/videos?id={video_id}&part=snippet,statistics&key={API_key}'
        response_video_stats = requests.get(url_video_stats).json()
        
        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        try:
            dislike_count = response_video_stats['items'][0]['statistics']['dislikeCount']
        except KeyError:
            dislike_count = 0  # Assign a default value if 'dislikeCount' key is not present

        comment_count = response_video_stats['items'][0]['statistics']['commentCount']
        
        return view_count,like_count,dislike_count,comment_count

# %%
def get_videos(df):
    # making API call
        pagetoken = ''
        url = f'https://www.googleapis.com/youtube/v3/search?key={API_key}&channelId={Channel_ID}&part=snippet,id&order=date&maxResults=1000&pageToken={pagetoken}'

        response = requests.get(url).json()
        time.sleep(1)
        
        for video in response['items']:
            if video['id']['kind'] == 'youtube#video':
                video_id = video['id']['videoId']
                video_title = video['snippet']['title']
                video_title = str(video_title).replace('&amp;','')
                upload_date = video['snippet']['publishedAt']
                upload_date = str(upload_date).split('T')[0]
        
                view_count, like_count, dislike_count, comment_count = get_video_details(video_id)
        
    #saving data in a pandas dataframe
                df = df.append({'video_id':video_id,'video_title':video_title,'upload_date':upload_date,'view_count':view_count,
                        'like_count':like_count,'dislike_count':dislike_count,'comment_count':comment_count}, ignore_index = True)
        return df

# %%
#main

# building pandas dataframe
df = pd.DataFrame(columns=['video_id','video_title','upload_date','view_count','like_count','dislike_count','comment_count'])

df = get_videos(df)
# Out:
# C:\Users\ZIA\AppData\Local\Temp\ipykernel_8724\299838167.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id,'video_title':video_title,'upload_date':upload_date,'view_count':view_count,
# C:\Users\ZIA\AppData\Local\Temp\ipykernel_8724\299838167.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id,'video_title':video_title,'upload_date':upload_date,'view_count':view_count,
# C:\Users\ZIA\AppData\Local\Temp\ipykernel_8724\299838167.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'video_id':video_id,'video_title':video_title,'upload_date':upload_date,'view_count':view_count,
# ...

# %%
df
# Out:
#        video_id                                        video_title  \
# 0   LOWGBvcqinA  집에서 새벽 스터디윗미🌙자기 전 딱 1시간! 백색소음 Midnight study w...
# 1   L0xhV-slGTQ  Eng) 의대생 Vlog | 국가고시 실기시험을 위한 한 달간의 노력과 역대급 스트...
# 2   8gPNOIgREk8  잘 쉬었으니 이제 공부해야지(요)? D-?? 의대생 스터디윗미 | 도서관에서 같이 ...
# 3   ytoQF_UfsiA  Eng) 의대생vlog | 방학 없이 태풍 뚫고 학교로,,,오늘도 찢었다🫠 시험기간...
# 4   M6BXqpIO73g  월화수목금토일 공부❤‍🔥한 달 같은 seven days a week~ #의대생 #브...
# 5   nccSM_XmIcw  Eng) 의대생vlog | 본과4학년 발등에 불똥 떨어진 중간고사 시험기간🔥효율적인...
# 6   Q8_LS4-JaJw  이 또한 지나가리라~ #의대생 #브이로그 #공부자극 #동기부여 #motivation...
# 7   CB5oeDCoUwk  Eng) 의대생vlog | 꽉잡아 멘탈☠매일 6시 기상 그리고 밤샘🎢롤러코스터 같았...
# 8   rsrQf2jIVq4  새 학년 도서관에서 의대생 스터디윗미 ✍🏻쉬지 않고 2시간 공부해요, 백색소음 St...
# 9   XxnAXVLYBZ8  🆘응급실에서 밤새우는 의대생 브이로그🌙 Day in the life of a kor...
# 10  xuYKfx2VZ9o  Eng) 의대생 Vlog | 밤샘공부와 밤샘실습🌙새벽4시 응급실 퇴근😴그동안 올리지...
# 11  w6M5nMqTSvo  Eng) 의대생Vlog | 본과 3학년 거북목이지만 마음만은 토끼🐰오늘도 밤샘 보고...
# 12  2y4LxhXReiQ  의대생 스터디윗미 📚도서관에서 1시간 시험공부 해요, 수능 화이팅! 백색소음 Stu...
# ...

# %%
df.to_csv('dia_ytchannel.csv',index=False, encoding='utf-8')
